# %%
from dask import dataframe
from dask.distributed import Client

# %%
client = Client(n_workers=2, threads_per_worker=2, memory_limit = '5 GB')
client
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/pytorch_env/lib/python3.9/site-packages/distributed/node.py:179: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 62615 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:62617' processes=2 threads=4, memory=9.31 GiB>

# %%
path = "/Users/luisramirez/Downloads/flights.parquet"
ddf = dataframe.read_parquet(path, engine="pyarrow", split_row_groups=True, chunksize='100 mb')
ddf.shape
# Out:
# (Delayed('int-74619bdd-ae57-4196-8e4b-aa50c6c5bd2c'), 61)

# %%
cols_drop = ddf.select_dtypes(['datetime', 'bool', 'object']).columns
ddf = ddf.drop(columns=cols_drop)
ddf.shape
# Out:
# (Delayed('int-aa27411f-21fb-4069-adb1-ab204d30eddf'), 41)

# %%
ddf.compute()
# Out:
#           CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# 0               1202   1157.0              0.0      -5.0   1256.0
# 1               1202   1157.0              0.0      -5.0   1258.0
# 2               1202   1153.0              0.0      -9.0   1302.0
# 3               1202   1150.0              0.0     -12.0   1253.0
# 4               1400   1355.0              0.0      -5.0   1459.0
# ...              ...      ...              ...       ...      ...
# 29193772        1617   1953.0            216.0     216.0   2256.0
# 29193773        1418   1801.0            223.0     223.0   1930.0
# 29193774        1750   2105.0            195.0     195.0   2201.0
# 29193776        2035   2309.0            154.0     154.0     52.0
# 29193779        1700   2318.0            378.0     378.0     59.0
#
#           ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  \
# 0                     0.0     38.0            62.0               59.0
# ...

# %%
X_sub = ddf.loc[0:10000]
persisted_ddf = X_sub.persist()
# Out:
# 2022-11-24 11:41:00,924 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.45 GiB -- Worker memory limit: 4.66 GiB
# 2022-11-24 11:42:03,871 - distributed.worker_memory - WARNING - Worker tcp://127.0.0.1:62639 (pid=48448) exceeded 95% memory budget. Restarting...
# 2022-11-24 11:42:04,361 - distributed.nanny - WARNING - Restarting worker
# 2022-11-24 11:42:06,621 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker-memory.html#memory-not-released-back-to-the-os for more information. -- Unmanaged memory: 3.48 GiB -- Worker memory limit: 4.66 GiB
# ...

# %%
persisted_ddf.head()
# Out:
# ---------------------------------------------------------------------------
# KilledWorker                              Traceback (most recent call last)
# /var/folders/l2/1myqjfqx5l74kp3rpcdvy7l00000gn/T/ipykernel_83833/652771576.py in <module>
# ----> 1 persisted_ddf.head()
#
# /opt/homebrew/Caskroom/miniforge/base/envs/pytorch_env/lib/python3.9/site-packages/dask/dataframe/core.py in head(self, n, npartitions, compute)
#    1254         # No need to warn if we're already looking at all partitions
#    1255         safe = npartitions != self.npartitions
# -> 1256         return self._head(n=n, npartitions=npartitions, compute=compute, safe=safe)
#    1257
#    1258     def _head(self, n, npartitions, compute, safe):
#
# /opt/homebrew/Caskroom/miniforge/base/envs/pytorch_env/lib/python3.9/site-packages/dask/dataframe/core.py in _head(self, n, npartitions, compute, safe)
#    1288
#    1289         if compute:
# -> 1290             result = result.compute()
# ...
